# %%
#!pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# !pip install data
# !pip install ssd
# !pip install imageio
# Out:
# ...
#   Using cached data-0.4.tar.gz (7.0 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached funcsigs-1.0.2-py2.py3-none-any.whl.metadata (14 kB)
# Using cached funcsigs-1.0.2-py2.py3-none-any.whl (17 kB)
# ...
#   Created wheel for data: filename=data-0.4-py3-none-any.whl size=7259 sha256=e015bdeb6f9262ae683ae46a64ac08fe91b1ca69e06725a84fbb7208991d396d
#   Stored in directory: c:\users\nithin\appdata\local\pip\cache\wheels\0e\90\87\0e55006f5c69af278687927041e334cfb928ab0a7ad9b0c1a3
# Successfully built data
# ...
#   Using cached ssd-1.0.0-py2.py3-none-any.whl.metadata (3.1 kB)
# ...
#   Using cached pypiwin32-223-py3-none-any.whl.metadata (236 bytes)
# ...
#   Using cached WMI-1.5.1-py2.py3-none-any.whl.metadata (3.6 kB)
# ...
# Using cached ssd-1.0.0-py2.py3-none-any.whl (5.3 kB)
# Using cached pypiwin32-223-py3-none-any.whl (1.7 kB)
# Using cached WMI-1.5.1-py2.py3-none-any.whl (28 kB)
# ...

# %%
import torch
from torch.autograd import variable,Function
import cv2
from data import BaseTransform,VOC_CLASSES as labelmap
from ssd import build_ssd
import imageio
import numpy as np

# %%
# !pip install imageio[ffmpeg]

# %%
class NewDetectFunction(Function):
    @staticmethod
    def forward(ctx, loc_data, conf_data, prior_data):
        # Your SSD detection logic should go here
        # Ensure it does not depend on self, making it static
        return loc_data, conf_data, prior_data


def detect(frame,net,transform):
    height,width=frame.shape[:2]
    frame_t=transform(frame)[0]
    x=torch.from_numpy(frame_t).permute(2,0,1)
    x=x.unsqueeze(0)
    x=x.float()
    y=net(x)
    detections=y.data
    scale=torch.Tensor([width,height,width,height])
    
    #detections=[batch,number of classes,no.of occurence,(score,x0,y0,x1,y1)]
    for i in range(detection.size(1)):
        j=0
        while detections[0,i,j,0]>=0.6:
            pt=(detectons[0,i,j,0]*scale)
            cv2.rectangle(frame,(int(pt[0]),int(pt[1])),(int(pt[2]),int(pt[3])),(255,0,0),2)
            cv2.putText(frame,labelmap[i-1],(int(pt[0]),int(pt[1])),cv2.FONT_HERSHEY_SIMPLEX,2,(255,255,255),2)
            
        j+=1
        return frame
    
net=build_ssd('test')
net.load_state_dict(torch.load('ssd300_mAP_77.43_v2.pth', map_location = lambda storage, loc: storage))
net.eval()

class BaseTransform:
    def __init__(self, size, mean):
        self.size = size
        self.mean = np.array(mean, dtype=np.float32)

    def __call__(self, img):
        img = cv2.resize(img, (self.size, self.size)).astype(np.float32)
        img -= self.mean
        img = img / 255.0
        
        # Ensure correct shape (batch, height, width, channels)
        img = img[np.newaxis, :, :, :]

        return img  # Add batch dimension

transform=BaseTransform(net.size,(104/256.0,117/256.0,123/256.0))

reader=imageio.get_reader('funny_dog.mp4')
fps=reader.get_meta_data()['fps']
writer=imageio.get_writer('Output.mp4',fps=fps)


for i,frame in enumerate(reader):
    frame=detect(frame,net,transform)
    writer.append(frame)
    print(i)
    
writer.close()
# Out:
# C:\Users\Nithin\AppData\Local\Temp\ipykernel_5004\2274960499.py:31: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
import torch
print(torch.cuda.is_available())  # Should return True if CUDA is properly set up
print(torch.cuda.device_count())  # Number of GPUs available
print(torch.cuda.get_device_name(0))  # Name of the first GPU
# Out:
# False
# 0
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2656\3482743971.py in <module>
#       2 print(torch.cuda.is_available())  # Should return True if CUDA is properly set up
#       3 print(torch.cuda.device_count())  # Number of GPUs available
# ----> 4 print(torch.cuda.get_device_name(0))  # Name of the first GPU
#
# c:\users\nithin\appdata\local\programs\python\python37\lib\site-packages\torch\cuda\__init__.py in get_device_name(device)
#     339         str: the name of the device
#     340     """
# --> 341     return get_device_properties(device).name
#     342
#     343
#
# c:\users\nithin\appdata\local\programs\python\python37\lib\site-packages\torch\cuda\__init__.py in get_device_properties(device)
#     369         _CudaDeviceProperties: the properties of the device
#     370     """
# ...

# %%
import torch
print("CUDA Available:", torch.cuda.is_available())
print("CUDA Version:", torch.version.cuda)
print("Device Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU found")
# Out:
# CUDA Available: True
# CUDA Version: 12.1
# Device Name: NVIDIA GeForce RTX 2050

# %%
import torch
print(torch.__version__)
# Out:
# 2.5.1+cu121
